# %% [markdown]
# # **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **LOADING THE DATASET**

# %%
df = pd.read_csv('hotel_booking.csv')

# %% [markdown]
# # **EDA AND DATA CLEANING**

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# returns the number of rows and columns present in this ....rows = 119390 and columns = 36
# Out:
# (119390, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %% [markdown]
# **NOTE**- AT LINE NUMBER 31 "reservation_status_date" IT IS IN OBJ FORM BUT IT SHOULD BE IN THE DATE FORMAT SO WE HAVE TO CHANGE IT TO THE DATE FORMAT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df["reservation_status_date"] = pd.to_datetime(df ['reservation_status_date'])

# %%
df.info()
# now it is converted in the date time format 
# jitne bhi object wale columns hain wo categorical columns hain so we can see that how many unique values are...
# ...present in the categorical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe(include  = 'object')
# generally the describe function is used for the numerical columns but for the....... 
# .....object columns it can be used with the help of 'include' function
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in df.describe(include  = 'object').columns:
    print (col);
    print (df[col].unique())
    print ('-'*80)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
# now we will cheack that how many missing values are present in every column 
df.isnull().sum()

# only 4 columns are present where values are missing 
# 1- childern , 2-country 3- agent 4 - company
# agent and comapny have large missing values so we will remove them
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['company' , 'agent'], axis=1, inplace= True)

# %%
df.dropna(inplace =True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# it is now used for the numerical columns ..IT SHOWS THE SUMMARY STATISTICS OF NUMERICAL COLUMNS 
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# HERE AS WE CAN SEE THAT OUTLIERS ARE PRESENT WHICH ARE IMPOSSIBLE TO HAPPEN SO WE HAVE TO REMOVE THOSE OUTLIERS FROM OUR DATASET...

# %%
df = df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # DATA ANALYSIS AND VISUALISATIONS

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize = True)
cancelled_perc

# now we are making the plot to visualize the percentage of cencelled bookings in both hotels with matplotlib library.

plt.figure(figsize =(5,4))
plt.title('Reservation Status Counts ')
plt.bar(['Not Canceled', 'Canceled'], df['is_canceled'].value_counts(), edgecolor= 'yellow', width = 0.7)
plt.show()
plt.savefig('Reservation Status Counts.jpg')

# In the provided code snippet, the normalize parameter in the value_counts() function is set to True....
# This parameter controls whether the returned counts are normalized or not.
# When normalize=True, the value_counts() function will return the relative frequencies or proportions......
# ....of each unique value in the 'is_canceled' column as a percentage of the total number of observations in the DataFrame.

# %% [markdown]
#  NOW WE WILL SEE THAT WHICH HOTEL HAS MORE CANCELLLATION RATIOS AND BY HOW MUCH SO WE HAVE DO SOMTHING ONLY IN THE 'IS_CANCELED'
#  COLUMN WITH THE HELP OF VISUALISATION IN SEABORN LIBRARY OF PYTHON

# %%
plt.figure(figsize = (8,4))

# since this is the categorical data which is 'is cancelled' and 'not cancelled' so there are plots for categorical datas in 
# seaborn library we will use here the count plot 

# fb vss bc
ax1= sns.countplot(x='hotel', hue= 'is_canceled', palette= 'Blues', data= df )
legend_labels,_=ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation Status in different hotels', size= 20)
# plt.ylabel("number of reservations")
# plt.xlabel('hotel')

plt.legend(['not canceled' , 'canceled'])
plt.show()
plt.savefig('Reservation Status in different hotels.jpg')

# %%
# from above we can observe that resort hotels have less bookings as compared to city hotels but in resort hotels 
# cancellation rates are low because they give better facilities i think an in city hotels facilities and other things
# are not quuite good thats why cancellation rates are high,

# so conclution is that city hotels need to be look more

# %%
df.head()
# adr = average daily rate
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize= True)

# we are fetching that how much percentage of bookings are getting cancelled in resort hotels
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize= True)

# we are fetching that how much percentage of bookings are getting cancelled in city hotels
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
resort_hotel= resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel= city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize =(20,8))
plt.title('Average daily rate in City and Resort Hotel', fontsize = 30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label= 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label= 'City Hotel')
plt.legend( fontsize =20)
plt.show()
plt.savefig('ADR in city and resort hotels.jpg')


# it clears ours hypothesis that city hotel price is less than resort hotel in some days

# %%
df['month']  =  df['reservation_status_date'].dt.month
plt.figure(figsize = (20,8))
ax2= sns.countplot(x = 'month' ,hue = 'is_canceled' ,data= df, palette = 'bright')
plt.legend(['not_canceled', 'canceled'])
plt.title('Reservation Status Per Month', size = 30 )
ax2.set_xlabel('Months', size = 25)
ax2.set_ylabel('Total number of reservations ', size = 20)
plt.show()
plt.savefig('Reservation Status per month.jpg')

# %%
# plotting average daily rate for each month

# %%
canceled_reservations_per_month = df[df['is_canceled'] == 1].groupby('month')['is_canceled'].count()
not_canceled_reservations_per_month = df[df['is_canceled'] == 0].groupby('month')['is_canceled'].count()
perc = canceled_reservations_per_month / (canceled_reservations_per_month + not_canceled_reservations_per_month)
perc*100 

# clearly august have minimum cancellation and january have maximum number of calcellations
# Out:
# month
# 1     57.051403
# 2     46.115527
# 3     37.515967
# 4     34.789595
# 5     30.483777
# 6     31.345219
# 7     36.110651
# 8     23.915174
# 9     28.400470
# 10    37.323119
# 11    37.978142
# 12    47.851509
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize=(20, 8))
plt.title('ADR per month for Canceled Reservations', fontsize=30)

# Filter the DataFrame to include only canceled reservations
canceled_df = df[df['is_canceled'] == 1]

# Group by month and calculate the sum of ADR for each month
adr_per_month = canceled_df.groupby('month')['adr'].sum().reset_index()

# Sort the DataFrame by month (optional, for better visualization)
adr_per_month = adr_per_month.sort_values(by='month')

# Create the bar plot
sns.barplot(x='month', y='adr', data=adr_per_month)

plt.xlabel('Months', fontsize=20)
plt.ylabel('Total ADR for Canceled Reservations', fontsize=20)

plt.show()
plt.savefig('ADR per month for cancelled reservation.jpg')

# %%
cancelled_data = df[df['is_canceled']==1]
top_10_countries = cancelled_data['country'].value_counts()[:10]
top_10_countries
# Out:
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# Name: country, dtype: int64

# %%
plt.figure(figsize= (8,8))
plt.title('Top 10 Countries With Reservation canceled')
plt.pie(top_10_countries, autopct = '%.2f', labels = top_10_countries.index ,pctdistance= 0.5 )
# autopct = '%.2f' it shows the perc number shown on pie upto 2 decimel places
plt.show()
plt.savefig('PIECHART Top 10 Countries With Reservation canceled.jpg')

# %%
# we made the hypothesis that mojority of clients are coming from the offline travel agents so we are going to cheack
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize = True )
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
# hence our hypothesis gone wrong ...online have more data than offline

# %%
cancelled_data['market_segment'].value_counts(normalize = True )
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
# there is similar situation in cancellation also
# here we can conclude that if the cancellation rates are higher in the online bookings 
# it means that when the customer is seeing the hotel in real 
# situation he is not pleased with that and hence cancel the reservation because the 
# rooms as shown in the pictures are totally different in real

# %%
m1= df[df['is_canceled']==1]['adr']
# m2 = len(df[df['is_canceled']==1]['adr'])
# m1/m2
m1
# Out:
# 8          82.0
# 9         105.5
# 10        123.0
# 27        107.0
# 32        108.3
#           ...
# 110280      0.0
# 111355     65.0
# 111924     65.0
# 111925     65.0
# 117295     65.0
# Name: adr, Length: 44152, dtype: float64

# %%
m2= df[df['is_canceled']==0]['adr']
# m4 = len(df[df['is_canceled']==0]['adr'])
# m3/m4
m2
# Out:
# 0           0.00
# 1           0.00
# 2          75.00
# 3          75.00
# 4          98.00
#            ...
# 119385     96.14
# 119386    225.43
# 119387    157.71
# 119388    104.40
# 119389    151.20
# Name: adr, Length: 74745, dtype: float64

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace = True)
cancelled_df_adr.sort_values('reservation_status_date', inplace = True)


not_cancelled_data = df[df['is_canceled']== 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace = True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace = True)


plt.figure(figsize = (20,6))
plt.title('Average Daily Rate', size = 30)
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label = 'cancelled')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label = 'not cancelled')
plt.legend()
